# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
from sklearn.datasets import load_digits

# %%
df = load_digits()

# %%
df_data = pd.DataFrame(df.data)

# %%
df_data.columns = df['feature_names']

# %%
df_data['target'] = df['target']

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn import tree

# %%
regressor = DecisionTreeRegressor()
regressor.fit(df.data[:20], df.target[:20])
# Out:
# DecisionTreeRegressor()

# %%
plt.rcParams['figure.figsize'] = (15,10)
tree.plot_tree(regressor,filled=True)
# Out:
# [Text(0.5833333333333334, 0.9166666666666666, 'x[2] <= 5.5\nsquared_error = 8.25\nsamples = 20\nvalue = 4.5'),
#  Text(0.35714285714285715, 0.75, 'x[25] <= 0.5\nsquared_error = 5.818\nsamples = 11\nvalue = 3.0'),
#  Text(0.19047619047619047, 0.5833333333333334, 'x[59] <= 5.0\nsquared_error = 3.2\nsamples = 5\nvalue = 5.0'),
#  Text(0.09523809523809523, 0.4166666666666667, 'x[53] <= 10.5\nsquared_error = 1.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.047619047619047616, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.14285714285714285, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.2857142857142857, 0.4166666666666667, 'x[30] <= 1.0\nsquared_error = 0.222\nsamples = 3\nvalue = 6.333'),
#  Text(0.23809523809523808, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.3333333333333333, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.5238095238095238, 0.5833333333333334, 'x[21] <= 13.5\nsquared_error = 1.889\nsamples = 6\nvalue = 1.333'),
#  Text(0.47619047619047616, 0.4166666666666667, 'x[22] <= 4.0\nsquared_error = 0.56\nsamples = 5\nvalue = 0.8'),
#  Text(0.42857142857142855, 0.25, 'x[29] <= 1.0\nsquared_error = 0.222\nsamples = 3\nvalue = 1.333'),
#  Text(0.38095238095238093, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.47619047619047616, 0.08333333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(0.5238095238095238, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(0.5714285714285714, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.8095238095238095, 0.75, 'x[9] <= 3.0\nsquared_error = 5.111\nsamples = 9\nvalue = 6.333'),
#  Text(0.7142857142857143, 0.5833333333333334, 'x[45] <= 14.5\nsquared_error = 1.889\nsamples = 6\nvalue = 7.667'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[58] <= 10.0\nsquared_error = 0.56\nsamples = 5\nvalue = 8.2'),
#  Text(0.6190476190476191, 0.25, 'squared_error = 0.0\nsamples = 2\nvalue = 9.0'),
#  Text(0.7142857142857143, 0.25, 'x[19] <= 5.0\nsquared_error = 0.222\nsamples = 3\nvalue = 7.667'),
#  Text(0.6666666666666666, 0.08333333333333333, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.7619047619047619, 0.08333333333333333, 'squared_error = 0.0\nsamples = 2\nvalue = 8.0'),
#  Text(0.7619047619047619, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.9047619047619048, 0.5833333333333334, 'x[3] <= 14.0\nsquared_error = 0.889\nsamples = 3\nvalue = 3.667'),
#  Text(0.8571428571428571, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.9523809523809523, 0.4166666666666667, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0')]

# %%
from sklearn.datasets import load_iris

# %%
dataset = load_iris()

# %%
classifier = DecisionTreeClassifier()
classifier.fit(dataset.data, dataset.target)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(classifier, filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]
